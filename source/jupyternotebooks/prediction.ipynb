# %% [markdown]
# # Prediction Mode

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>This mode is used if the nature/label of the event is not known in advance. </b>
# </div>

# %% [markdown]
# ## Download data

# %% [markdown]
# Input data should be in **mseed** format and correspond to raw **60 second 3-component seismograms**.

# %% [markdown]
# Demo data is available in the "mseed" folder.

# %% [markdown]
# To apply the algorithm, we need a folder architecture:
# * mseed_demo
#    * 2022004T134407
#         * FR_CHLF_2022004T134407.mseed
#         * FR_GARF_2022004T134407.mseed
#         * FR_GNEF_2022004T134407.mseed
#         * FR_VERF_2022004T134407.mseed
#
# The name of the mseed file should be formatted as "{network} _ {station} _ {time_event}.mseed".
#
# A csv file is also required to apply the algorithm.
# It is composed of a column with folders/events to discriminate.

# %%
import pandas as pd

# %%
pred_net_csv = pd.read_csv("../files/pred.csv")
pred_net_csv = pd.DataFrame(pred_net_csv)
pred_net_csv.head()
# Out:
#               time  label_cat
# 0  20160323T082644          0
# 1  20191226T212102          0
# 2  20160914T204901          0
# 3  20181023T112338          0
# 4  20181113T141901          0

# %%
len(pred_net_csv)
# Out:
# 3607

# %% [markdown]
# ## Run prediction

# %% [markdown]
# ### From a terminal:

# %% [markdown]
# ```
#  python run.py --data_dir ./mseed_demo --spectro_dir ./spectro_demo --output_dir ./output_demo --csv_dir demo_pred.csv
# ```

# %% [markdown]
# ### From a notebook:

# %%
import sys
sys.path.append('../../discrimination_eq_q/')

import numpy as np 

from data_process import spectro_extract
from prediction import discrim
# Out:
# 2024-03-13 17:11:08.363074: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-13 17:11:08.516500: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-13 17:11:08.516529: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-13 17:11:08.516975: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-13 17:11:08.599974: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-13 17:11:08.601702: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 17:11:09.963478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
events = np.genfromtxt(f'../files/pred.csv', delimiter=',', skip_header = 1, dtype=str)
events
# Out:
# array([['20160323T082644', '0'],
#        ['20191226T212102', '0'],
#        ['20160914T204901', '0'],
#        ...,
#        ['20230518T171142', '0'],
#        ['20200901T093703', '0'],
#        ['20150311T200151', '0']], dtype='<U15')

# %%
#data = spectro_extract(data_dir="./../../map_dir/mseed", spectro_dir="./../spectro_demo", events_list=events)

# %%
discrim(model_dir='../../discrimination_eq_q/model/model_2021354T1554.h5',
        spectro_dir='../files/spectro/',
        output_dir='../files/output/',
        event_label=events,
        valid = True)
# Out:
# Number of events: 7895
# *****************
# EVENT 1 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 64ms/step
# *****************
# EVENT 2 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 4 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 5 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 6 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 7 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 8 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 9 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 10 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 11 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 12 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 13 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 14 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 15 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 16 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 17 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 18 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 19 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 20 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 21 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 22 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 23 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 24 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 25 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 26 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 27 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 28 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 29 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 30 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 31 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 32 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 33 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 34 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 35 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 36 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 37 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 38 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 39 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 40 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 41 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 42 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 43 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 44 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 45 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 46 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 47 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 48 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 49 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 50 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 51 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 52 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 53 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 54 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 55 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 56 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 57 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 58 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 59 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 60 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 61 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 62 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 63 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 64 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 65 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 66 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 67 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 68 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 69 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 70 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 71 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 72 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 73 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 74 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 75 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 76 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 77 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 78 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 79 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 80 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 81 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 82 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 83 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 84 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 85 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 86 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 87 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 88 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 89 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 90 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 91 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 92 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 93 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 94 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 28ms/step
# *****************
# EVENT 95 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 96 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 97 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 98 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 99 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 100 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 101 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 102 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 103 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 104 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 105 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 106 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 107 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 108 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 109 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 110 / 3607
# Number of station: 0
# Error: float division by zero
# *****************
# EVENT 111 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 112 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 113 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 114 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 115 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 116 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 117 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 118 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 119 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 120 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 121 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 122 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 123 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 124 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 125 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 126 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 127 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 128 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 129 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 130 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 131 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 132 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 31ms/step
# *****************
# EVENT 133 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 134 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 135 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 136 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 137 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 138 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 139 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 140 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 141 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 142 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 143 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 144 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 145 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 146 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 147 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 148 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 149 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 150 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 151 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 152 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 153 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 154 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 155 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 156 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 157 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 158 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 159 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 160 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
# *****************
# EVENT 161 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 162 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 163 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 25ms/step
# *****************
# EVENT 164 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 165 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 166 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# *****************
# EVENT 167 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 168 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 169 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 170 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 171 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 172 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 173 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 174 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 175 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 176 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 24ms/step
# *****************
# EVENT 177 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 178 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 179 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 180 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 181 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
# *****************
# EVENT 182 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 183 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 184 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 185 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 186 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 187 / 3607
# Number of station: 0
# Error: float division by zero
# *****************
# EVENT 188 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 189 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 190 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 191 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 192 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 193 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
# *****************
# EVENT 194 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 195 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 196 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 197 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 198 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 199 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 200 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 201 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 202 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 203 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 204 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 205 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 206 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 207 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 208 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 209 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 210 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 211 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 212 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 213 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 214 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 215 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 216 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 217 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 218 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 219 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 220 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 221 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 222 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 223 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 224 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 225 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 226 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 227 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 228 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 229 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 230 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 231 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 32ms/step
# *****************
# EVENT 232 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 29ms/step
# *****************
# EVENT 233 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 33ms/step
# *****************
# EVENT 234 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 32ms/step
# *****************
# EVENT 235 / 3607
# Number of station: 3
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 236 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 237 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 238 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 239 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 240 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 241 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 242 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 243 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 244 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 245 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 246 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 247 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 248 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 249 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 250 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 251 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 252 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 253 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 254 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 255 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 256 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 257 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 258 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 259 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 260 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 261 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 262 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 263 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 264 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 265 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 266 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 267 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 26ms/step
# *****************
# EVENT 268 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 269 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 270 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 271 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 272 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 273 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 274 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 275 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 276 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 277 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 278 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 279 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 280 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 281 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 282 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 283 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 284 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 285 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 286 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 287 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 288 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 289 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 30ms/step
# *****************
# EVENT 290 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 291 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 292 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 293 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 294 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 295 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 296 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 297 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 298 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 299 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 31ms/step
# *****************
# EVENT 300 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 301 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 302 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 303 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 304 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 305 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 306 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 307 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 308 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 309 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 310 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 24ms/step
# *****************
# EVENT 311 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 312 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 313 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 314 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 315 / 3607
# Number of station: 0
# Error: float division by zero
# *****************
# EVENT 316 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 30ms/step
# *****************
# EVENT 317 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 318 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 319 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 320 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 321 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 322 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 323 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 324 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 325 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 326 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 327 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 328 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 329 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 330 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 31ms/step
# *****************
# EVENT 331 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 332 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 333 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 334 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 335 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 336 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 337 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 338 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 339 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 340 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 24ms/step
# *****************
# EVENT 341 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 342 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 343 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 344 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 345 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 346 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 347 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 348 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 349 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 350 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 351 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 352 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 353 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 354 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 355 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 356 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 357 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 358 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 359 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 360 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 361 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 362 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 363 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 364 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 365 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 25ms/step
# *****************
# EVENT 366 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 367 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 368 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 369 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 370 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 371 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 372 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 373 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 374 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 375 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 376 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 25ms/step
# *****************
# EVENT 377 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 378 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 379 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 380 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 381 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 382 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 383 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 384 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 25ms/step
# *****************
# EVENT 385 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 25ms/step
# *****************
# EVENT 386 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 387 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 388 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 389 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 390 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 391 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 392 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 24ms/step
# *****************
# EVENT 393 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 394 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 395 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 396 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 397 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 24ms/step
# *****************
# EVENT 398 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 25ms/step
# *****************
# EVENT 399 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 400 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 401 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 402 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 403 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 404 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 25ms/step
# *****************
# EVENT 405 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 406 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 407 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 408 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 409 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 410 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 411 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 412 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 413 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 414 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 415 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 416 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 417 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 418 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 419 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 420 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 421 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 33ms/step
# *****************
# EVENT 422 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 423 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 424 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 425 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 426 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 427 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 428 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 429 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 430 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 431 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 432 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 433 / 3607
# Number of station: 1
# ...
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3468 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3469 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3470 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3471 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3472 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3473 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3474 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3475 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3476 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3477 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3478 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 3479 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3480 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 30ms/step
# *****************
# EVENT 3481 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 3482 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3483 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 3484 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3485 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3486 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3487 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3488 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3489 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3490 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3491 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3492 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3493 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3494 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3495 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3496 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3497 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3498 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3499 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3500 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3501 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3502 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3503 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3504 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3505 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3506 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 3507 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 3508 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3509 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3510 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3511 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 3512 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3513 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3514 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3515 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3516 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3517 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3518 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3519 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3520 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 34ms/step
# *****************
# EVENT 3521 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 3522 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3523 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3524 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 3525 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3526 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3527 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3528 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3529 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3530 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3531 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3532 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3533 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3534 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3535 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3536 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3537 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3538 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3539 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3540 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3541 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3542 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3543 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3544 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3545 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3546 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3547 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3548 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3549 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3550 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3551 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3552 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3553 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3554 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3555 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3556 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3557 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3558 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3559 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3560 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3561 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 21ms/step
# *****************
# EVENT 3562 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 26ms/step
# *****************
# EVENT 3563 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3564 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3565 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3566 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3567 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3568 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3569 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3570 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3571 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3572 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3573 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3574 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 44ms/step
# *****************
# EVENT 3575 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3576 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3577 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3578 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3579 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 19ms/step
# *****************
# EVENT 3580 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3581 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3582 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3583 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3584 / 3607
# Number of station: 3
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# *****************
# EVENT 3585 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3586 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3587 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3588 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3589 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3590 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3591 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3592 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
# *****************
# EVENT 3593 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3594 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
# *****************
# EVENT 3595 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3596 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# *****************
# EVENT 3597 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3598 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3599 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
# *****************
# EVENT 3600 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
# *****************
# EVENT 3601 / 3607
# Number of station: 2
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3602 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 20ms/step
# *****************
# EVENT 3603 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 22ms/step
# *****************
# EVENT 3604 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 26ms/step
# *****************
# EVENT 3605 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 28ms/step
# *****************
# EVENT 3606 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step
# *****************
# EVENT 3607 / 3607
# Number of station: 1
# 1/1 [==============================] - 0s 23ms/step

# %% [markdown]
# ## Read csv file

# %%
import pandas as pd

# %%
pred_net_csv = pd.read_csv("../output_demo/prediction_network_level.csv")
pred_net_csv = pd.DataFrame(pred_net_csv)
pred_net_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pred_net_csv = pd.read_csv("../output_demo/prediction_network_level.csv")
#       2 pred_net_csv = pd.DataFrame(pred_net_csv)
#       3 pred_net_csv.head()
#
# File ~/.config/geo/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/.config/geo/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/.config/geo/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/.config/geo/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/.config/geo/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output_demo/prediction_network_level.csv'

# %%
pred_sta_csv

# %%
pred_sta_csv = pd.read_csv("../files/prediction_station_level.csv")
pred_sta_csv = pd.DataFrame(pred_sta_csv)
pred_sta_csv.head()
# Out:
#                   file_name station  prob_nat  prob_ant  pred         nature
# 0  BL_BB19B_20170305T161215   BB19B     0.260     0.740     1  Anthropogenic
# 1   BL_PTGB_20200115T115752    PTGB     0.940     0.060     0        Natural
# 2   NB_NBAN_20160323T082644    NBAN     0.998     0.002     0        Natural
# 3   NB_NBTA_20191226T212102    NBTA     0.668     0.332     0        Natural
# 4   NB_NBRF_20160914T204901    NBRF     0.034     0.966     1  Anthropogenic

# %%
pred_sta_csv[pred_sta_csv['nature'] == 'Anthropogenic']

# %%
Natural_pred_sta_csv = pred_sta_csv[pred_sta_csv['nature'] == 'Natural']

# %% [markdown]
# ## Probabilidade baixa

# %%
Natural_pred_sta_csv[Natural_pred_sta_csv['prob_nat'] < 0.79]

# %%
Natural_pred_sta_csv[(Natural_pred_sta_csv['station'] == 'IT1') & (Natural_pred_sta_csv['prob_nat'] < 0.79)]

# %%
Natural_pred_sta_csv[(Natural_pred_sta_csv['station'] == 'IT9') & (Natural_pred_sta_csv['prob_nat'] < 0.79)]
