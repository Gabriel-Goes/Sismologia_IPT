# %% [markdown]
# # Validation Mode

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>This mode is used if the nature/label of the event is known in advance. </b>
# </div>

# %% [markdown]
# ## Download data

# %% [markdown]
# Input data should be in **mseed** format and correspond to raw **60 second 3-component seismograms**.

# %% [markdown]
# Demo data is available in the "mseed" folder.

# %% [markdown]
# To apply the algorithm, we need a folder architecture:
# * mseed_demo
#    * 2022004T134407
#         * FR_CHLF_2022004T134407.mseed
#         * FR_GARF_2022004T134407.mseed
#         * FR_GNEF_2022004T134407.mseed
#         * FR_VERF_2022004T134407.mseed
#
# The name of the mseed file should be formatted as "{network} _ {station} _ {time_event}.mseed".

# %% [markdown]
# To apply this mode, a **csv file** import pandas as pd is also required with the associated label for each event.

# %%
import pandas as pd
import numpy as np 
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import roc_curve, roc_auc_score, classification_report, confusion_matrix, accuracy_score

# %%
import sys
sys.path.append('../')

from data_process import spectro_extract
from prediction import discrim
# Out:
# 2023-12-21 10:08:48.849219: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-21 10:08:48.872548: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 10:08:48.872581: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 10:08:48.872598: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 10:08:48.877284: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-21 10:08:48.878073: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-21 10:08:49.573052: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Run validation

# %%
events = np.genfromtxt(f'./../../map_dir/event_test.csv', delimiter=',', skip_header = 1, dtype=str)

# %%
data = spectro_extract(data_dir="./../../map_dir/mseed", spectro_dir="./../../map_dir/spectro", events_list=events)
# Out:
# Number of events: 99
#   0%|                                                                                                                                  | 0/99 [00:00<?, ?it/s]
# *****************
# EVENT 1 / 99
# Number of streams: 1
# Stream 1 / 1
#   2%|██▍                                                                                                                       | 2/99 [00:00<00:20,  4.63it/s]
# *****************
# EVENT 2 / 99
# Number of streams: 1
# *****************
# EVENT 3 / 99
# Number of streams: 1
# Stream 1 / 1
#   4%|████▉                                                                                                                     | 4/99 [00:00<00:16,  5.70it/s]
# *****************
# EVENT 4 / 99
# Number of streams: 1
# *****************
# EVENT 5 / 99
# Number of streams: 1
# Stream 1 / 1
#   6%|███████▍                                                                                                                  | 6/99 [00:01<00:15,  5.82it/s]
# *****************
# EVENT 6 / 99
# Number of streams: 1
# *****************
# EVENT 7 / 99
# Number of streams: 1
# Stream 1 / 1
#   8%|█████████▊                                                                                                                | 8/99 [00:01<00:15,  5.83it/s]
# *****************
# EVENT 8 / 99
# Number of streams: 1
# *****************
# EVENT 9 / 99
# Number of streams: 1
# Stream 1 / 1
#  10%|████████████▏                                                                                                            | 10/99 [00:01<00:14,  6.11it/s]
# *****************
# EVENT 10 / 99
# Number of streams: 1
# *****************
# EVENT 11 / 99
# Number of streams: 1
# Stream 1 / 1
#  12%|██████████████▋                                                                                                          | 12/99 [00:02<00:13,  6.22it/s]
# *****************
# EVENT 12 / 99
# Number of streams: 1
# *****************
# EVENT 13 / 99
# Number of streams: 1
# Stream 1 / 1
#  14%|█████████████████                                                                                                        | 14/99 [00:02<00:13,  6.11it/s]
# *****************
# EVENT 14 / 99
# Number of streams: 1
# *****************
# EVENT 15 / 99
# Number of streams: 1
# Stream 1 / 1
#  16%|███████████████████▌                                                                                                     | 16/99 [00:02<00:13,  6.25it/s]
# *****************
# EVENT 16 / 99
# Number of streams: 1
# *****************
# EVENT 17 / 99
# Number of streams: 1
# Stream 1 / 1
#  18%|██████████████████████                                                                                                   | 18/99 [00:03<00:12,  6.31it/s]
# *****************
# EVENT 18 / 99
# Number of streams: 1
# *****************
# EVENT 19 / 99
# Number of streams: 1
# Stream 1 / 1
#  20%|████████████████████████▍                                                                                                | 20/99 [00:03<00:12,  6.32it/s]
# *****************
# EVENT 20 / 99
# Number of streams: 1
# *****************
# EVENT 21 / 99
# Number of streams: 1
# Stream 1 / 1
#  22%|██████████████████████████▉                                                                                              | 22/99 [00:03<00:12,  6.25it/s]
# *****************
# EVENT 22 / 99
# Number of streams: 1
# *****************
# EVENT 23 / 99
# Number of streams: 1
# Stream 1 / 1
#  24%|█████████████████████████████▎                                                                                           | 24/99 [00:04<00:12,  6.17it/s]
# *****************
# EVENT 24 / 99
# Number of streams: 1
# *****************
# EVENT 25 / 99
# Number of streams: 1
# Stream 1 / 1
#  26%|███████████████████████████████▊                                                                                         | 26/99 [00:04<00:11,  6.24it/s]
# *****************
# EVENT 26 / 99
# Number of streams: 1
# *****************
# EVENT 27 / 99
# Number of streams: 1
# Stream 1 / 1
#  28%|██████████████████████████████████▏                                                                                      | 28/99 [00:04<00:11,  6.25it/s]
# *****************
# EVENT 28 / 99
# Number of streams: 1
# *****************
# EVENT 29 / 99
# Number of streams: 1
# Stream 1 / 1
#  30%|████████████████████████████████████▋                                                                                    | 30/99 [00:04<00:10,  6.29it/s]
# *****************
# EVENT 30 / 99
# Number of streams: 1
# *****************
# EVENT 31 / 99
# Number of streams: 1
# Stream 1 / 1
#  32%|███████████████████████████████████████                                                                                  | 32/99 [00:05<00:10,  6.35it/s]
# *****************
# EVENT 32 / 99
# Number of streams: 1
# *****************
# EVENT 33 / 99
# Number of streams: 1
# Stream 1 / 1
#  34%|█████████████████████████████████████████▌                                                                               | 34/99 [00:05<00:10,  6.42it/s]
# *****************
# EVENT 34 / 99
# Number of streams: 1
# *****************
# EVENT 35 / 99
# Number of streams: 1
# Stream 1 / 1
#  36%|████████████████████████████████████████████                                                                             | 36/99 [00:05<00:09,  6.42it/s]
# *****************
# EVENT 36 / 99
# Number of streams: 1
# *****************
# EVENT 37 / 99
# Number of streams: 1
# Stream 1 / 1
#  38%|██████████████████████████████████████████████▍                                                                          | 38/99 [00:06<00:09,  6.39it/s]
# *****************
# EVENT 38 / 99
# Number of streams: 1
# *****************
# EVENT 39 / 99
# Number of streams: 1
# Stream 1 / 1
#  40%|████████████████████████████████████████████████▉                                                                        | 40/99 [00:06<00:09,  6.41it/s]
# *****************
# EVENT 40 / 99
# Number of streams: 1
# *****************
# EVENT 41 / 99
# Number of streams: 1
# Stream 1 / 1
#  42%|███████████████████████████████████████████████████▎                                                                     | 42/99 [00:06<00:08,  6.42it/s]
# *****************
# EVENT 42 / 99
# Number of streams: 1
# *****************
# EVENT 43 / 99
# Number of streams: 1
# Stream 1 / 1
#  44%|█████████████████████████████████████████████████████▊                                                                   | 44/99 [00:07<00:08,  6.45it/s]
# *****************
# EVENT 44 / 99
# Number of streams: 1
# *****************
# EVENT 45 / 99
# Number of streams: 1
# Stream 1 / 1
#  46%|████████████████████████████████████████████████████████▏                                                                | 46/99 [00:07<00:08,  6.44it/s]
# *****************
# EVENT 46 / 99
# Number of streams: 1
# *****************
# EVENT 47 / 99
# Number of streams: 1
# Stream 1 / 1
#  48%|██████████████████████████████████████████████████████████▋                                                              | 48/99 [00:07<00:07,  6.46it/s]
# *****************
# EVENT 48 / 99
# Number of streams: 1
# *****************
# EVENT 49 / 99
# Number of streams: 1
# Stream 1 / 1
#  51%|█████████████████████████████████████████████████████████████                                                            | 50/99 [00:08<00:07,  6.45it/s]
# *****************
# EVENT 50 / 99
# Number of streams: 1
# *****************
# EVENT 51 / 99
# Number of streams: 1
# Stream 1 / 1
#  53%|███████████████████████████████████████████████████████████████▌                                                         | 52/99 [00:08<00:07,  6.43it/s]
# *****************
# EVENT 52 / 99
# Number of streams: 1
# *****************
# EVENT 53 / 99
# Number of streams: 1
# Stream 1 / 1
#  55%|██████████████████████████████████████████████████████████████████                                                       | 54/99 [00:08<00:06,  6.43it/s]
# *****************
# EVENT 54 / 99
# Number of streams: 1
# *****************
# EVENT 55 / 99
# Number of streams: 1
# Stream 1 / 1
#  57%|████████████████████████████████████████████████████████████████████▍                                                    | 56/99 [00:09<00:06,  6.41it/s]
# *****************
# EVENT 56 / 99
# Number of streams: 1
# *****************
# EVENT 57 / 99
# Number of streams: 1
# Stream 1 / 1
#  59%|██████████████████████████████████████████████████████████████████████▉                                                  | 58/99 [00:09<00:06,  6.35it/s]
# *****************
# EVENT 58 / 99
# Number of streams: 1
# *****************
# EVENT 59 / 99
# Number of streams: 1
# Stream 1 / 1
#  61%|█████████████████████████████████████████████████████████████████████████▎                                               | 60/99 [00:09<00:06,  6.31it/s]
# *****************
# EVENT 60 / 99
# Number of streams: 1
# *****************
# EVENT 61 / 99
# Number of streams: 1
# Stream 1 / 1
#  63%|███████████████████████████████████████████████████████████████████████████▊                                             | 62/99 [00:09<00:05,  6.35it/s]
# *****************
# EVENT 62 / 99
# Number of streams: 1
# *****************
# EVENT 63 / 99
# Number of streams: 1
# Stream 1 / 1
#  65%|██████████████████████████████████████████████████████████████████████████████▏                                          | 64/99 [00:10<00:05,  6.39it/s]
# *****************
# EVENT 64 / 99
# Number of streams: 1
# *****************
# EVENT 65 / 99
# Number of streams: 1
# Stream 1 / 1
#  67%|████████████████████████████████████████████████████████████████████████████████▋                                        | 66/99 [00:10<00:05,  6.31it/s]
# *****************
# EVENT 66 / 99
# Number of streams: 1
# *****************
# EVENT 67 / 99
# Number of streams: 1
# Stream 1 / 1
#  69%|███████████████████████████████████████████████████████████████████████████████████                                      | 68/99 [00:10<00:05,  6.16it/s]
# *****************
# EVENT 68 / 99
# Number of streams: 1
# *****************
# EVENT 69 / 99
# Number of streams: 1
# Stream 1 / 1
#  71%|█████████████████████████████████████████████████████████████████████████████████████▌                                   | 70/99 [00:11<00:04,  6.24it/s]
# *****************
# EVENT 70 / 99
# Number of streams: 1
# *****************
# EVENT 71 / 99
# Number of streams: 1
# Stream 1 / 1
#  73%|████████████████████████████████████████████████████████████████████████████████████████                                 | 72/99 [00:11<00:04,  6.33it/s]
# *****************
# EVENT 72 / 99
# Number of streams: 1
# *****************
# EVENT 73 / 99
# Number of streams: 1
# Stream 1 / 1
#  75%|██████████████████████████████████████████████████████████████████████████████████████████▍                              | 74/99 [00:11<00:03,  6.32it/s]
# *****************
# EVENT 74 / 99
# Number of streams: 1
# *****************
# EVENT 75 / 99
# Number of streams: 1
# Stream 1 / 1
#  77%|████████████████████████████████████████████████████████████████████████████████████████████▉                            | 76/99 [00:12<00:03,  6.29it/s]
# *****************
# EVENT 76 / 99
# Number of streams: 1
# *****************
# EVENT 77 / 99
# Number of streams: 1
# Stream 1 / 1
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████▎                         | 78/99 [00:12<00:03,  6.30it/s]
# *****************
# EVENT 78 / 99
# Number of streams: 1
# *****************
# EVENT 79 / 99
# Number of streams: 1
# Stream 1 / 1
#  81%|█████████████████████████████████████████████████████████████████████████████████████████████████▊                       | 80/99 [00:12<00:02,  6.39it/s]
# *****************
# EVENT 80 / 99
# Number of streams: 1
# *****************
# EVENT 81 / 99
# Number of streams: 1
# Stream 1 / 1
#  83%|████████████████████████████████████████████████████████████████████████████████████████████████████▏                    | 82/99 [00:13<00:02,  6.27it/s]
# *****************
# EVENT 82 / 99
# Number of streams: 1
# *****************
# EVENT 83 / 99
# Number of streams: 1
# Stream 1 / 1
#  85%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋                  | 84/99 [00:13<00:02,  6.34it/s]
# *****************
# EVENT 84 / 99
# Number of streams: 1
# *****************
# EVENT 85 / 99
# Number of streams: 1
# Stream 1 / 1
#  87%|█████████████████████████████████████████████████████████████████████████████████████████████████████████                | 86/99 [00:13<00:02,  6.39it/s]
# *****************
# EVENT 86 / 99
# Number of streams: 1
# *****************
# EVENT 87 / 99
# Number of streams: 1
# Stream 1 / 1
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▌             | 88/99 [00:14<00:01,  6.37it/s]
# *****************
# EVENT 88 / 99
# Number of streams: 1
# *****************
# EVENT 89 / 99
# Number of streams: 1
# Stream 1 / 1
#  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████           | 90/99 [00:14<00:01,  6.29it/s]
# *****************
# EVENT 90 / 99
# Number of streams: 1
# *****************
# EVENT 91 / 99
# Number of streams: 1
# Stream 1 / 1
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍        | 92/99 [00:14<00:01,  6.30it/s]
# *****************
# EVENT 92 / 99
# Number of streams: 1
# *****************
# EVENT 93 / 99
# Number of streams: 1
# Stream 1 / 1
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉      | 94/99 [00:15<00:00,  6.36it/s]
# *****************
# EVENT 94 / 99
# Number of streams: 1
# *****************
# EVENT 95 / 99
# Number of streams: 1
# Stream 1 / 1
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 96/99 [00:15<00:00,  6.39it/s]
# *****************
# EVENT 96 / 99
# Number of streams: 1
# *****************
# EVENT 97 / 99
# Number of streams: 1
# Stream 1 / 1
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 98/99 [00:15<00:00,  6.41it/s]
# *****************
# EVENT 98 / 99
# Number of streams: 1
# *****************
# EVENT 99 / 99
# Number of streams: 1
# Stream 1 / 1
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 99/99 [00:15<00:00,  6.26it/s]

# %%
discrim(model_dir="./../model/model_2021354T1554.h5", spectro_dir='./../spectro_demo', output_dir="./../output_demo", event_label=events, valid = True)
# Out:
# Number of events: 1634
#   0%|                                                                                                                                  | 0/99 [00:00<?, ?it/s]
# *****************
# EVENT 1 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 73ms/step
#   1%|█▏                                                                                                                        | 1/99 [00:00<00:10,  9.28it/s]
#  ---> 20230929145625 => [0.02500000037252903, 0.9750000238418579]
# *****************
# EVENT 2 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230929111457 => [0.20999999344348907, 0.7900000214576721]
# *****************
# EVENT 3 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230929103129 => [0.028999999165534973, 0.9710000157356262]
# *****************
# EVENT 4 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#   4%|████▉                                                                                                                     | 4/99 [00:00<00:04, 20.67it/s]
#  ---> 20230929100122 => [0.004999999888241291, 0.9950000047683716]
# *****************
# EVENT 5 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
#  ---> 20230927124624 => [0.8489999771118164, 0.1509999930858612]
# *****************
# EVENT 6 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  ---> 20230926204946 => [0.012000000104308128, 0.9879999756813049]
# *****************
# EVENT 7 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
#   7%|████████▋                                                                                                                 | 7/99 [00:00<00:03, 23.90it/s]
#  ---> 20230926175326 => [0.8840000033378601, 0.11599999666213989]
# *****************
# EVENT 8 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230926164356 => [0.8389999866485596, 0.16099999845027924]
# *****************
# EVENT 9 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
#  ---> 20230926115317 => [0.20200000703334808, 0.7979999780654907]
# *****************
# EVENT 10 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
#  10%|████████████▏                                                                                                            | 10/99 [00:00<00:03, 25.13it/s]
#  ---> 20230926004239 => [0.7369999885559082, 0.2630000114440918]
# *****************
# EVENT 11 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230921102418 => [0.6679999828338623, 0.3319999873638153]
# *****************
# EVENT 12 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
#  ---> 20230921100544 => [0.5550000071525574, 0.4449999928474426]
# *****************
# EVENT 13 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  13%|███████████████▉                                                                                                         | 13/99 [00:00<00:03, 26.24it/s]
#  ---> 20230919120542 => [0.5230000019073486, 0.47699999809265137]
# *****************
# EVENT 14 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230919025258 => [0.08100000023841858, 0.9190000295639038]
# *****************
# EVENT 15 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
#  ---> 20230918191802 => [0.5860000252723694, 0.414000004529953]
# *****************
# EVENT 16 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  16%|███████████████████▌                                                                                                     | 16/99 [00:00<00:03, 26.84it/s]
#  ---> 20230916152149 => [0.012000000104308128, 0.9879999756813049]
# *****************
# EVENT 17 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230916042829 => [0.7509999871253967, 0.24899999797344208]
# *****************
# EVENT 18 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230906151824 => [0.9900000095367432, 0.009999999776482582]
# *****************
# EVENT 19 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  19%|███████████████████████▏                                                                                                 | 19/99 [00:00<00:04, 19.13it/s]
#  ---> 20230906121305 => [0.7649999856948853, 0.23499999940395355]
# *****************
# EVENT 20 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230904002008 => [0.9430000185966492, 0.05700000002980232]
# *****************
# EVENT 21 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  ---> 20230902081604 => [0.22699999809265137, 0.7730000019073486]
# *****************
# EVENT 22 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  22%|██████████████████████████▉                                                                                              | 22/99 [00:00<00:03, 21.65it/s]
#  ---> 20230831155622 => [0.5920000076293945, 0.40799999237060547]
# *****************
# EVENT 23 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230830183917 => [0.17800000309944153, 0.8220000267028809]
# *****************
# EVENT 24 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230830183917 => [0.17800000309944153, 0.8220000267028809]
# *****************
# EVENT 25 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  25%|██████████████████████████████▌                                                                                          | 25/99 [00:01<00:03, 23.52it/s]
#  ---> 20230829223229 => [0.8669999837875366, 0.13300000131130219]
# *****************
# EVENT 26 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 29ms/step
#  ---> 20230829051603 => [0.5609999895095825, 0.4390000104904175]
# *****************
# EVENT 27 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230826033100 => [0.6740000247955322, 0.32600000500679016]
# *****************
# EVENT 28 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  28%|██████████████████████████████████▏                                                                                      | 28/99 [00:01<00:03, 22.14it/s]
#  ---> 20230824152934 => [0.017999999225139618, 0.9819999933242798]
# *****************
# EVENT 29 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  ---> 20230824120837 => [0.43799999356269836, 0.5619999766349792]
# *****************
# EVENT 30 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230824105740 => [0.23999999463558197, 0.7599999904632568]
# *****************
# EVENT 31 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  31%|█████████████████████████████████████▉                                                                                   | 31/99 [00:01<00:02, 24.04it/s]
#  ---> 20230822160656 => [0.5249999761581421, 0.4749999940395355]
# *****************
# EVENT 32 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230822153204 => [0.03400000184774399, 0.9660000205039978]
# *****************
# EVENT 33 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230821122338 => [0.13300000131130219, 0.8669999837875366]
# *****************
# EVENT 34 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 18ms/step
#  34%|█████████████████████████████████████████▌                                                                               | 34/99 [00:01<00:02, 25.17it/s]
#  ---> 20230821120934 => [0.03200000151991844, 0.9679999947547913]
# *****************
# EVENT 35 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
#  ---> 20230821120548 => [0.01600000075995922, 0.984000027179718]
# *****************
# EVENT 36 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230821111316 => [0.08299999684095383, 0.9169999957084656]
# *****************
# EVENT 37 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  37%|█████████████████████████████████████████████▏                                                                           | 37/99 [00:01<00:02, 25.64it/s]
#  ---> 20230818154804 => [0.039000000804662704, 0.9610000252723694]
# *****************
# EVENT 38 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230818115628 => [0.14499999582767487, 0.8550000190734863]
# *****************
# EVENT 39 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230818113723 => [0.03500000014901161, 0.9649999737739563]
# *****************
# EVENT 40 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  40%|████████████████████████████████████████████████▉                                                                        | 40/99 [00:01<00:02, 25.94it/s]
#  ---> 20230818110409 => [0.6420000195503235, 0.3580000102519989]
# *****************
# EVENT 41 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230818105254 => [0.367000013589859, 0.6330000162124634]
# *****************
# EVENT 42 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230818105158 => [0.2070000022649765, 0.7929999828338623]
# *****************
# EVENT 43 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  43%|████████████████████████████████████████████████████▌                                                                    | 43/99 [00:01<00:02, 26.72it/s]
#  ---> 20230818105114 => [0.2070000022649765, 0.7929999828338623]
# *****************
# EVENT 44 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230818105008 => [0.4090000092983246, 0.5910000205039978]
# *****************
# EVENT 45 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230818102159 => [0.625, 0.375]
# *****************
# EVENT 46 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  46%|████████████████████████████████████████████████████████▏                                                                | 46/99 [00:01<00:01, 27.10it/s]
#  ---> 20230818102033 => [0.0729999989271164, 0.9269999861717224]
# *****************
# EVENT 47 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230818101831 => [0.7300000190734863, 0.27000001072883606]
# *****************
# EVENT 48 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230817172033 => [0.23100000619888306, 0.7689999938011169]
# *****************
# EVENT 49 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  49%|███████████████████████████████████████████████████████████▉                                                             | 49/99 [00:02<00:01, 27.10it/s]
#  ---> 20230817101051 => [0.6420000195503235, 0.3580000102519989]
# *****************
# EVENT 50 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230817100659 => [0.44699999690055847, 0.5529999732971191]
# *****************
# EVENT 51 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
#  ---> 20230817043502 => [0.13500000536441803, 0.8650000095367432]
# *****************
# EVENT 52 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  53%|███████████████████████████████████████████████████████████████▌                                                         | 52/99 [00:02<00:01, 27.54it/s]
#  ---> 20230816172754 => [0.22699999809265137, 0.7730000019073486]
# *****************
# EVENT 53 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230816165806 => [0.21400000154972076, 0.7860000133514404]
# *****************
# EVENT 54 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230816124754 => [0.2770000100135803, 0.7229999899864197]
# *****************
# EVENT 55 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  56%|███████████████████████████████████████████████████████████████████▏                                                     | 55/99 [00:02<00:01, 28.00it/s]
#  ---> 20230816111833 => [0.052000001072883606, 0.9480000138282776]
# *****************
# EVENT 56 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230815203545 => [0.44999998807907104, 0.550000011920929]
# *****************
# EVENT 57 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230815192736 => [0.0, 1.0]
# *****************
# EVENT 58 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  59%|██████████████████████████████████████████████████████████████████████▉                                                  | 58/99 [00:02<00:01, 27.88it/s]
#  ---> 20230815191541 => [0.7839999794960022, 0.2160000056028366]
# *****************
# EVENT 59 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
#  ---> 20230815152902 => [0.06800000369548798, 0.9319999814033508]
# *****************
# EVENT 60 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 15ms/step
#  ---> 20230814152826 => [0.06400000303983688, 0.9359999895095825]
# *****************
# EVENT 61 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  62%|██████████████████████████████████████████████████████████████████████████▌                                              | 61/99 [00:02<00:01, 27.15it/s]
#  ---> 20230811103532 => [0.8050000071525574, 0.19499999284744263]
# *****************
# EVENT 62 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  ---> 20230811040402 => [0.45399999618530273, 0.5460000038146973]
# *****************
# EVENT 63 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230810142951 => [0.8159999847412109, 0.18400000035762787]
# *****************
# EVENT 64 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  65%|██████████████████████████████████████████████████████████████████████████████▏                                          | 64/99 [00:02<00:01, 27.82it/s]
#  ---> 20230809143252 => [0.15199999511241913, 0.8479999899864197]
# *****************
# EVENT 65 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230809105318 => [0.5640000104904175, 0.4359999895095825]
# *****************
# EVENT 66 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230808180349 => [0.9190000295639038, 0.08100000023841858]
# *****************
# EVENT 67 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  ---> 20230808180348 => [0.8859999775886536, 0.11400000005960464]
# *****************
# EVENT 68 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 17ms/step
#  69%|███████████████████████████████████████████████████████████████████████████████████                                      | 68/99 [00:02<00:01, 28.06it/s]
#  ---> 20230808124749 => [0.09000000357627869, 0.9100000262260437]
# *****************
# EVENT 69 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 24ms/step
#  ---> 20230807150411 => [0.6620000004768372, 0.33799999952316284]
# *****************
# EVENT 70 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230807150407 => [0.9700000286102295, 0.029999999329447746]
# *****************
# EVENT 71 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
#  72%|██████████████████████████████████████████████████████████████████████████████████████▊                                  | 71/99 [00:02<00:01, 25.42it/s]
#  ---> 20230807132955 => [0.6039999723434448, 0.3959999978542328]
# *****************
# EVENT 72 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230803183724 => [0.007000000216066837, 0.9929999709129333]
# *****************
# EVENT 73 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230803180211 => [0.05999999865889549, 0.9399999976158142]
# *****************
# EVENT 74 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  75%|██████████████████████████████████████████████████████████████████████████████████████████▍                              | 74/99 [00:02<00:00, 26.46it/s]
#  ---> 20230803152117 => [0.33799999952316284, 0.6620000004768372]
# *****************
# EVENT 75 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230803115117 => [0.43299999833106995, 0.5669999718666077]
# *****************
# EVENT 76 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230802202746 => [0.003000000026077032, 0.996999979019165]
# *****************
# EVENT 77 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  78%|██████████████████████████████████████████████████████████████████████████████████████████████                           | 77/99 [00:03<00:00, 27.09it/s]
#  ---> 20230802154527 => [0.9819999933242798, 0.017999999225139618]
# *****************
# EVENT 78 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230802150815 => [0.09200000017881393, 0.9079999923706055]
# *****************
# EVENT 79 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  ---> 20230801200625 => [0.890999972820282, 0.10899999737739563]
# *****************
# EVENT 80 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  81%|█████████████████████████████████████████████████████████████████████████████████████████████████▊                       | 80/99 [00:03<00:00, 27.28it/s]
#  ---> 20230801195912 => [0.8360000252723694, 0.164000004529953]
# *****************
# EVENT 81 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230801182340 => [0.05999999865889549, 0.9399999976158142]
# *****************
# EVENT 82 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230801181715 => [0.27000001072883606, 0.7300000190734863]
# *****************
# EVENT 83 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 16ms/step
#  84%|█████████████████████████████████████████████████████████████████████████████████████████████████████▍                   | 83/99 [00:03<00:00, 26.32it/s]
#  ---> 20230801130545 => [0.33500000834465027, 0.6650000214576721]
# *****************
# EVENT 84 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230731163813 => [0.25, 0.75]
# *****************
# EVENT 85 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230731161723 => [0.2849999964237213, 0.7149999737739563]
# *****************
# EVENT 86 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  87%|█████████████████████████████████████████████████████████████████████████████████████████████████████████                | 86/99 [00:03<00:00, 27.04it/s]
#  ---> 20230731125529 => [0.5410000085830688, 0.45899999141693115]
# *****************
# EVENT 87 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230728123512 => [0.11800000071525574, 0.8820000290870667]
# *****************
# EVENT 88 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230727193328 => [0.8019999861717224, 0.1979999989271164]
# *****************
# EVENT 89 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▊            | 89/99 [00:03<00:00, 27.81it/s]
#  ---> 20230727173713 => [0.652999997138977, 0.34700000286102295]
# *****************
# EVENT 90 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230727154330 => [0.125, 0.875]
# *****************
# EVENT 91 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230727130811 => [0.6349999904632568, 0.36500000953674316]
# *****************
# EVENT 92 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍        | 92/99 [00:03<00:00, 27.40it/s]
#  ---> 20230726163231 => [0.007000000216066837, 0.9929999709129333]
# *****************
# EVENT 93 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  ---> 20230725171337 => [0.6150000095367432, 0.38499999046325684]
# *****************
# EVENT 94 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230725170213 => [0.9449999928474426, 0.054999999701976776]
# *****************
# EVENT 95 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████     | 95/99 [00:03<00:00, 27.40it/s]
#  ---> 20230725144848 => [0.5759999752044678, 0.42399999499320984]
# *****************
# EVENT 96 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
#  ---> 20230725094426 => [0.5090000033378601, 0.4909999966621399]
# *****************
# EVENT 97 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 12ms/step
#  ---> 20230724165951 => [0.13099999725818634, 0.8690000176429749]
# *****************
# EVENT 98 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 13ms/step
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 98/99 [00:03<00:00, 28.01it/s]
#  ---> 20230724155534 => [0.8550000190734863, 0.14499999582767487]
# *****************
# EVENT 99 / 99
# Number of station: 1
# 1/1 [==============================] - 0s 14ms/step
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 99/99 [00:03<00:00, 25.88it/s]
#  ---> 20230724135651 => [0.1080000028014183, 0.8920000195503235]

# %% [markdown]
# # Predições em Rede

# %%
pred_net = pd.read_csv("../output_demo/validation_network_level.csv")
pred_net.sort_values(by='prob_ant',ascending=False).head(10)
# Out:
#              event  label_cat  prob_nat  prob_ant  pred         nature
# 56  20230815192736          1     0.000     1.000     1  Anthropogenic
# 75  20230802202746          1     0.003     0.997     1  Anthropogenic
# 3   20230929100122          0     0.005     0.995     1  Anthropogenic
# 91  20230726163231          1     0.007     0.993     1  Anthropogenic
# 71  20230803183724          0     0.007     0.993     1  Anthropogenic
# 5   20230926204946          1     0.012     0.988     1  Anthropogenic
# 15  20230916152149          1     0.012     0.988     1  Anthropogenic
# 34  20230821120548          0     0.016     0.984     1  Anthropogenic
# 27  20230824152934          1     0.018     0.982     1  Anthropogenic
# 0   20230929145625          0     0.025     0.975     1  Anthropogenic

# %%
#df_events = pd.DataFrame(events,columns=['event','label_cat','mag','lat','lon'])
#df_events

# %%
#df_concat = pd.concat([df_events,pred_net['pred']], axis=1)
#df_concat

# %%
#df_concat = pd.concat([df_concat,pred_net['prob_nat']], axis=1)
#df_concat

# %%
#df_concat['mag'] = df_concat['mag'].astype(float)

# %%
#df_concat['mag']

# %%
#df_concat.describe()

# %%
#df_concat.to_csv('/home/ipt/projetos/map_dir/events_processed.csv', index=False)

# %% [markdown]
# ### Rótulos dos sismos

# %%
print('SIMSMOS ROTULADOS COMO:')
sismo_natural = pred_net[pred_net['label_cat'] == 0]
print(f'    sismos naturais - > {len(sismo_natural)}')
sismo_antrop = pred_net[pred_net['label_cat'] == 1]
print(f'    sismos antrópicos - > {len(sismo_antrop)}')
# Out:
# SIMSMOS ROTULADOS COMO:
#     sismos naturais - > 67
#     sismos antrópicos - > 32

# %%
print('SIMSMOS CLASSIFICADOS COMO:')
sismo_falso_natural = sismo_antrop[sismo_antrop['pred'] == 0 ]
print(f'    sismos naturais falsos - > {len(sismo_falso_natural)}')
sismo_falso_antro = sismo_natural[sismo_natural['pred'] == 1 ]
print(f'    sismos antropogênicos falsos - > {len(sismo_falso_antro)}')
# Out:
# SIMSMOS CLASSIFICADOS COMO:
#     sismos naturais falsos - > 11
#     sismos antropogênicos falsos - > 36

# %%
# Suponha que você tenha as seguintes listas de probabilidades para eventos naturais e antropogênicos
prob_anthropogenic = sismo_antrop['prob_nat']
prob_natural = sismo_natural['prob_nat']

# Calcular frequências em porcentagem
freq_natural, bins_natural = np.histogram(prob_natural, bins=np.arange(0, 1.1, 0.1))
freq_anthropogenic, bins_anthropogenic = np.histogram(prob_anthropogenic, bins=np.arange(0, 1.1, 0.1))

# Convert frequency to percentage of the test size
freq_natural = (freq_natural / len(sismo_natural)) *100
freq_anthropogenic = (freq_anthropogenic / len(sismo_antrop))*100

# As posições dos centros dos bins para plotar
bin_centers = (bins_natural[:-1] + bins_natural[1:]) / 2

# Criar o gráfico de linhas
plt.figure(figsize=(16, 9))
plt.plot(bin_centers, freq_natural, marker='s', color='blue', label='Natural')
plt.plot(bin_centers, freq_anthropogenic, marker='o', color='orange', label='Anthropogenic')

# Adicionar anotações com a porcentagem em cima de cada ponto do gráfico
for x, y in zip(bin_centers, freq_natural):
    if y > 0:  # Only annotate if the percentage is greater than 0
        plt.text(x, y, f"{y:.1f}", ha='center', va='bottom')
for x, y in zip(bin_centers, freq_anthropogenic):
    if y > 0:  # Only annotate if the percentage is greater than 0
        plt.text(x, y, f"{y:.1f}", ha='center', va='bottom')

# Configurando os ticks do eixo x e y
plt.xticks(np.arange(0, 1.1, 0.1))
plt.yticks(np.arange(0, 101, 10))

# Adicionar legendas, títulos e rótulos
plt.legend()
plt.title('Probability Distribution of "Natural" vs "Anthropogenic" Events at Station Level')
plt.xlabel('Probability of "Natural" Earthquake')
plt.ylabel('% of Test Size')

# Mostrar o gráfico
plt.grid(True)
plt.show()

# %%
# Suponha que seu DataFrame seja algo como:
df = pred_net

# Extraindo os rótulos verdadeiros e previstos
y_true = df['label_cat']
y_pred = df['pred']

# Calculando a acurácia
accuracy = accuracy_score(y_true, y_pred)
print("Acurácia:", accuracy)

# Gerando o relatório de classificação
report = classification_report(y_true, y_pred)
print("\nRelatório de Classificação:\n", report)

# Gerando a matriz de confusão
conf_matrix = confusion_matrix(y_true, y_pred)
print("\nMatriz de Confusão:\n", conf_matrix)

# Criando a matriz de confusão
conf_matrix = confusion_matrix(y_true, y_pred)

# Usando Seaborn para criar um heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Reds')

# Adicionando títulos e rótulos
plt.title('Matriz de Confusão ( Network )')
plt.ylabel('Verdadeiro')
plt.xlabel('Previsto')

# Ajustando os rótulos (se necessário)
# plt.xticks(ticks=[0.5, 1.5], labels=['Classe 0', 'Classe 1'])
# plt.yticks(ticks=[0.5, 1.5], labels=['Classe 0', 'Classe 1'])

plt.show()
# Out:
# Acurácia: 0.5252525252525253
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.74      0.46      0.57        67
#            1       0.37      0.66      0.47        32
#
#     accuracy                           0.53        99
#    macro avg       0.55      0.56      0.52        99
# weighted avg       0.62      0.53      0.54        99
#
#
# Matriz de Confusão:
#  [[31 36]
#  [11 21]]

# %%
# Extraindo os rótulos verdadeiros e as probabilidades previstas
y_true = df['label_cat']
y_scores = df['prob_ant']

# Calculando a curva ROC e a AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = roc_auc_score(y_true, y_scores)

# Plotando a curva ROC
plt.figure(figsize=(12, 9))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falsos Positivos')
plt.ylabel('Taxa de Verdadeiros Positivos')
plt.title('Curva ROC ( Network )')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Predições em Estação

# %%
pred_sta = pd.read_csv("../output_demo/validation_station_level.csv")
pred_sta.head()
# Out:
#                 file_name station  label_cat  prob_nat  prob_ant  pred  \
# 0   MC_MC9_20230929145625     MC9          0     0.025     0.975     1
# 1   MC_MC9_20230929111457     MC9          0     0.210     0.790     1
# 2   MC_MC9_20230929103129     MC9          0     0.029     0.971     1
# 3   MC_MC9_20230929100122     MC9          0     0.005     0.995     1
# 4  MC_BCM2_20230927124624    BCM2          0     0.849     0.151     0
#
#           nature
# 0  Anthropogenic
# 1  Anthropogenic
# 2  Anthropogenic
# 3  Anthropogenic
# 4        Natural

# %%
sismo_natural = pred_sta[pred_sta['label_cat'] == 0]
print(f'sismos naturais - > {len(sismo_natural)}')

sismo_antrop = pred_sta[pred_sta['label_cat'] == 1]
print(f'sismos antrópicos - > {len(sismo_antrop)}')
# Out:
# sismos naturais - > 67
# sismos antrópicos - > 32

# %%
sismo_falso_natural = sismo_antrop[sismo_antrop['pred'] == 0 ]
print(f'sismos naturais falsos - > {len(sismo_falso_natural)}')

sismo_falso_antro = sismo_natural[sismo_natural['pred'] == 1 ]
print(f'sismos antropogênicos falsos - > {len(sismo_falso_antro)}')
# Out:
# sismos naturais falsos - > 11
# sismos antropogênicos falsos - > 36

# %%
sismo_verdadeiro_natural = sismo_natural[sismo_natural['pred'] == 0 ]
print(f'sismos naturais verdadeiros - > {len(sismo_verdadeiro_natural)}')

sismo_verdadeiro_antro = sismo_antrop[sismo_antrop['pred'] == 1 ]
print(f'sismos antropogênicos verdadeiros - > {len(sismo_verdadeiro_antro)}')
# Out:
# sismos naturais verdadeiros - > 31
# sismos antropogênicos verdadeiros - > 21

# %%
# Suponha que você tenha as seguintes listas de probabilidades para eventos naturais e antropogênicos
prob_anthropogenic = sismo_antrop['prob_nat']
prob_natural = sismo_natural['prob_nat']

# Calcular frequências em porcentagem
freq_natural, bins_natural = np.histogram(prob_natural, bins=np.arange(0, 1.1, 0.1))
freq_anthropogenic, bins_anthropogenic = np.histogram(prob_anthropogenic, bins=np.arange(0, 1.1, 0.1))

# Convert frequency to percentage of the test size
freq_natural = (freq_natural / len(prob_natural)) * 100
freq_anthropogenic = (freq_anthropogenic / len(prob_anthropogenic)) * 100

# As posições dos centros dos bins para plotar
bin_centers = (bins_natural[:-1] + bins_natural[1:]) / 2

# Criar o gráfico de linhas
plt.figure(figsize=(12, 9))
plt.plot(bin_centers, freq_natural, marker='s', color='blue', label='Natural')
plt.plot(bin_centers, freq_anthropogenic, marker='o', color='orange', label='Anthropogenic')

# Adicionar anotações com a porcentagem em cima de cada ponto do gráfico
for x, y in zip(bin_centers, freq_natural):
    if y > 0:  # Only annotate if the percentage is greater than 0
        plt.text(x, y, f"{y:.1f}", ha='center', va='bottom')
for x, y in zip(bin_centers, freq_anthropogenic):
    if y > 0:  # Only annotate if the percentage is greater than 0
        plt.text(x, y, f"{y:.1f}", ha='center', va='bottom')

# Configurando os ticks do eixo x e y
plt.xticks(np.arange(0, 1.1, 0.1))
plt.yticks(np.arange(0, 101, 10))

# Adicionar legendas, títulos e rótulos
plt.legend()
plt.title('Probability Distribution of "Natural" vs "Anthropogenic" Events at Network Level')
plt.xlabel('Probability of "Natural" Earthquake')
plt.ylabel('% of Test Size')

# Mostrar o gráfico
plt.grid(True)
plt.show()

# %%
# Suponha que seu DataFrame seja algo como:
df = pred_sta

# Extraindo os rótulos verdadeiros e previstos
y_true = df['label_cat']
y_pred = df['pred']

# Calculando a acurácia
accuracy = accuracy_score(y_true, y_pred)
print("Acurácia:", accuracy)

# Gerando o relatório de classificação
report = classification_report(y_true, y_pred)
print("\nRelatório de Classificação:\n", report)

# Gerando a matriz de confusão
conf_matrix = confusion_matrix(y_true, y_pred)
print("\nMatriz de Confusão:\n", conf_matrix)

# Criando a matriz de confusão
conf_matrix = confusion_matrix(y_true, y_pred)

# Usando Seaborn para criar um heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Reds')

# Adicionando títulos e rótulos
plt.title('Matriz de Confusão ( Stations )')
plt.ylabel('Verdadeiro')
plt.xlabel('Previsto')

# Ajustando os rótulos (se necessário)
# plt.xticks(ticks=[0.5, 1.5], labels=['Classe 0', 'Classe 1'])
# plt.yticks(ticks=[0.5, 1.5], labels=['Classe 0', 'Classe 1'])

plt.show()
# Out:
# Acurácia: 0.5252525252525253
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.74      0.46      0.57        67
#            1       0.37      0.66      0.47        32
#
#     accuracy                           0.53        99
#    macro avg       0.55      0.56      0.52        99
# weighted avg       0.62      0.53      0.54        99
#
#
# Matriz de Confusão:
#  [[31 36]
#  [11 21]]

# %%
# Extraindo os rótulos verdadeiros e as probabilidades previstas
y_true = df['label_cat']
y_scores = df['prob_ant']

# Calculando a curva ROC e a AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = roc_auc_score(y_true, y_scores)

# Plotando a curva ROC
plt.figure(figsize=(12, 9))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falsos Positivos')
plt.ylabel('Taxa de Verdadeiros Positivos')
plt.title('Curva ROC  ( Stations )')
plt.legend(loc="lower right")
plt.show()
